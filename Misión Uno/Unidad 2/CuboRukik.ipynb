# %% [markdown]
# ## Método Fridrich:
#
# Es el método más utilizado por los speedcubers. Consiste en resolver el cubo en cuatro pasos:
# - Cruz: Resolver una cruz de color amarillo en la capa superior.
# - F2L: Resolver las dos primeras capas del cubo, formando bloques de piezas.
# - OLL: Orientar las piezas de la última capa.
# - PLL: Permutar las piezas de la última capa.

# %%
def solve_white_cross():
    print("1. Resolver la cruz blanca.")
    # Describe los movimientos necesarios para alinear los bordes blancos con los centros correspondientes.

def solve_white_corners():
    print("2. Posicionar y orientar las esquinas blancas.")
    # Detalla cómo colocar las esquinas blancas en su lugar.

def solve_second_layer():
    print("3. Completar la segunda capa, excluyendo la capa superior.")
    # Explica los movimientos para alinear los bordes de la segunda capa.

def solve_yellow_cross():
    print("4. Formar la cruz amarilla en la cara superior.")
    # Indica cómo formar una cruz amarilla en la cara opuesta a la blanca.

def position_yellow_corners():
    print("5. Posicionar las esquinas amarillas sin orientar.")
    # Describe el proceso para colocar las esquinas amarillas en la posición correcta.

def orient_yellow_corners():
    print("6. Orientar las esquinas amarillas.")
    # Proporciona los movimientos necesarios para orientar correctamente las esquinas amarillas.

def finalize_last_layer():
    print("7. Ajustar los bordes de la última capa.")
    # Describe los últimos ajustes en la orientación de los bordes de la última capa.

def solve_rubiks_cube():
    print("Inicio del proceso de resolución del Cubo de Rubik:")
    solve_white_cross()
    solve_white_corners()
    solve_second_layer()
    solve_yellow_cross()
    position_yellow_corners()
    orient_yellow_corners()
    finalize_last_layer()
    print("El cubo de Rubik ha sido resuelto.")

# Ejecutar el programa
solve_rubiks_cube()
# Out:
# Inicio del proceso de resolución del Cubo de Rubik:
# 1. Resolver la cruz blanca.
# 2. Posicionar y orientar las esquinas blancas.
# 3. Completar la segunda capa, excluyendo la capa superior.
# 4. Formar la cruz amarilla en la cara superior.
# 5. Posicionar las esquinas amarillas sin orientar.
# 6. Orientar las esquinas amarillas.
# 7. Ajustar los bordes de la última capa.
# El cubo de Rubik ha sido resuelto.

# %% [markdown]
# ## Solución con clases

# %%
class RubiksCube:
    def __init__(self):
        self.cube = self.initialize_cube()

    def initialize_cube(self):
        # Inicializa un cubo resuelto
        return {
            'U': [['Y']*3 for _ in range(3)],  # Cara superior (Yellow)
            'D': [['W']*3 for _ in range(3)],  # Cara inferior (White)
            'F': [['G']*3 for _ in range(3)],  # Cara frontal (Green)
            'B': [['B']*3 for _ in range(3)],  # Cara trasera (Blue)
            'L': [['O']*3 for _ in range(3)],  # Cara izquierda (Orange)
            'R': [['R']*3 for _ in range(3)]   # Cara derecha (Red)
        }

    def display(self):
        # Muestra el estado actual del cubo
        for face in self.cube:
            print(f"{face}:")
            for row in self.cube[face]:
                print(" ".join(row))
            print()

    def move(self, steps):
        # Simula movimientos del cubo
        print(f"Aplicando movimientos: {steps}")
        # Aquí iría la lógica para manipular la estructura de datos del cubo según los movimientos

    def solve_white_cross(self):
        print("Resolviendo la cruz blanca...")
        # Aquí irían los algoritmos para resolver la cruz blanca

    def solve_white_corners(self):
        print("Posicionando las esquinas blancas...")
        # Algoritmos para las esquinas blancas

    def solve_second_layer(self):
        print("Resolviendo la segunda capa...")
        # Algoritmos para la segunda capa

    def solve_yellow_cross(self):
        print("Creando la cruz amarilla...")
        # Algoritmos para la cruz amarilla

    def position_yellow_corners(self):
        print("Posicionando las esquinas amarillas...")
        # Algoritmos para posicionar las esquinas amarillas

    def orient_yellow_corners(self):
        print("Orientando las esquinas amarillas...")
        # Algoritmos para orientar las esquinas amarillas

    def finalize_last_layer(self):
        print("Perfeccionando la última capa...")
        # Algoritmos para ajustar la última capa

    def solve(self):
        self.solve_white_cross()
        self.solve_white_corners()
        self.solve_second_layer()
        self.solve_yellow_cross()
        self.position_yellow_corners()
        self.orient_yellow_corners()
        self.finalize_last_layer()
        print("¡El cubo ha sido resuelto!")

# Uso del programa
cube = RubiksCube()
cube.display()
cube.solve()
# Out:
# U:
# Y Y Y
# Y Y Y
# Y Y Y
#
# D:
# W W W
# W W W
# W W W
#
# F:
# G G G
# G G G
# G G G
#
# B:
# B B B
# B B B
# B B B
#
# L:
# O O O
# O O O
# O O O
#
# R:
# R R R
# R R R
# R R R
#
# Resolviendo la cruz blanca...
# Posicionando las esquinas blancas...
# Resolviendo la segunda capa...
# Creando la cruz amarilla...
# Posicionando las esquinas amarillas...
# Orientando las esquinas amarillas...
# Perfeccionando la última capa...
# ¡El cubo ha sido resuelto!
